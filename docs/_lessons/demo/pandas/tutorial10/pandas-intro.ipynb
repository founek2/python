# %% [markdown]
# # Pandas = Python Data Analysis Library

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread('panda.jpeg'))

# %% [markdown]
# Knihovna pro práci s daty v tabulkovém formátu.

# %%
import pandas as pd # Konvence je importovat pandas cely pod nazvem pd

# %%
# Zakladni datovy typ - DataFrame (tabulka)
df = pd.DataFrame([
    [10, 1],
    [20, 2],
    [30, 3]
], columns=['First', 'Second'])

df
# Out:
#    First  Second
# 0     10       1
# 1     20       2
# 2     30       3

# %%
# Jednolive sloupce tabulky jsou pristupne podle jejich nazvu
df['First'] # df.First
# Out:
# 0    10
# 1    20
# 2    30
# Name: First, dtype: int64

# %%
# K radkum podle indexu 
df.loc[2]
# Out:
# First     30
# Second     3
# Name: 2, dtype: int64

# %%
## podle jmena
display(df.loc[0, 'First']) # klasicky plati [radek, sloupe]
## podle poradi
display(df.iloc[0, 0])
## podle podminky
display(df.loc[df['First'] == 20])

# Muzeme i vyrezavat (slice)
display(df.iloc[0:2, :])
# Out:
# 10
# 10
#    First  Second
# 1     20       2
#    First  Second
# 0     10       1
# 1     20       2

# %%
# Nazvy sloupcu jsou vlaste take indexy,
# ale vetsinou se setkame s argumentem columns pro sloupecky a index pro radky
# Z toho duvodu se casto pracuje se sloupecky a radky podobne

df.mean(axis='index') # df.mean(axis=0)
# Out:
# First     20.0
# Second     2.0
# dtype: float64

# %%
df.mean(axis='columns') # df.mean(axis=1)
# Out:
# 0     5.5
# 1    11.0
# 2    16.5
# dtype: float64

# %%
df.T
# Out:
#          0   1   2
# First   10  20  30
# Second   1   2   3

# %%
# Z vystupu vydime, ze vystup operace se sloupecky a radky je podobny - tzv. Series (druhy zakladni typ v pandas)
# Series - 1D pole, DataFrame 2D pole
series = pd.Series(['a', 'b', 'b'])
series
# Out:
# 0    a
# 1    b
# 2    b
# dtype: object

# %%
# Prirazeni
df.loc[0, 'First'] = None # jedna bunka
df['New'] = list(range(len(df)))
df
# Out:
#    First  Second  New
# 0    NaN       1    0
# 1   20.0       2    1
# 2   30.0       3    2

# %%
# Typy
## Zakladni typy - int, float, string, datatime + object
df['String'] = series
df['Object'] = [1, 'a', None]

display(df)

display(df.info())
# Out:
#    First  Second  New String Object
# 0    NaN       1    0      a      1
# 1   20.0       2    1      b      a
# 2   30.0       3    2      b   None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   First   2 non-null      float64
#  1   Second  3 non-null      int64
#  2   New     3 non-null      int64
#  3   String  3 non-null      object
#  4   Object  2 non-null      object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 248.0+ bytes
# None

# %%
# Hledani unikatnich hodnot
df['String'].unique()
# Out:
# array(['a', 'b'], dtype=object)

# %%
# Nahrazovani
df['String'].replace({'a': 'c'})
# Out:
# 0    c
# 1    b
# 2    b
# Name: String, dtype: object

# %%
# Prace s NaN hodnotami (docela slozita)
display(df['Object'].isna())

display(df['Object'].fillna(1))


df['First'].sum()
# Out:
# 0    False
# 1    False
# 2     True
# Name: Object, dtype: bool
# 0    1
# 1    a
# 2    1
# Name: Object, dtype: object
# 50.0

# %%
# Statistika
df.agg(['mean', 'sum', 'count'])
# Out:
# /var/folders/34/jqppgbvx07sd661m451nwtc40000gn/T/ipykernel_48568/4003580195.py:2: FutureWarning: ['String', 'Object'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.agg(['mean', 'sum', 'count'])
#        First  Second  New String  Object
# mean    25.0     2.0  1.0    NaN     NaN
# sum     50.0     6.0  3.0    abb     NaN
# count    2.0     3.0  3.0      3     2.0

# %%
# nebo postupne
df.mean()
df.sum()
# Out:
# /var/folders/34/jqppgbvx07sd661m451nwtc40000gn/T/ipykernel_48568/2959837415.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# /var/folders/34/jqppgbvx07sd661m451nwtc40000gn/T/ipykernel_48568/2959837415.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum()
# First     50.0
# Second       6
# New          3
# String     abb
# dtype: object

# %%
# nebo vse najednou
df.describe()
# Out:
#            First  Second  New
# count   2.000000     3.0  3.0
# mean   25.000000     2.0  1.0
# std     7.071068     1.0  1.0
# min    20.000000     1.0  0.0
# 25%    22.500000     1.5  0.5
# 50%    25.000000     2.0  1.0
# 75%    27.500000     2.5  1.5
# max    30.000000     3.0  2.0

# %%
# vizualizace

df.plot('New', 'Second', marker='o')
# Out:
# <AxesSubplot:xlabel='New'>

# %% [markdown]
# .. A spousta dalsich veci.
#
# Jako v zaklanim pythonu plati pravidlo. Kdyz neco chci udelat, zkusim Google jestli to uz neni nahodnou implementovane.
